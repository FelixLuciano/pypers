# %% [markdown]
# # **Newsletter example**

# %% [markdown]
# ## **🔧 Config**

# %%
from src import page, google


# https://docs.google.com/spreadsheets/d/1gHyAd0czD_clb49oRxC8hjYMl8Mvhgl3kjBG7BqnA78/edit#gid=0
users = google.Sheets.fetch_table('1gHyAd0czD_clb49oRxC8hjYMl8Mvhgl3kjBG7BqnA78', 'Subscribers')
users.mail_column = 'email'
users.name_column = 'name'

# %% [markdown]
# ## **🔠 Props**

# %%
import datetime


_now = datetime.datetime.now()
date = _now.strftime(f"%B %d of %Y")

date
# Out:
# 'July 13 of 2022'

# %%
@page.user_prop
def first_name(user):
    return user["name"].split(' ')[0]

# %%
import ipywidgets as widgets

title = widgets.Text(description='Title:', value='Lorem ipsum dolor sit amet')

title
# Out:
# Text(value='Lorem ipsum dolor sit amet', description='Title:')

# %% [markdown]
# ## **🔍 Preview**

# %%
page.preview()
# Out:
# HBox(children=(Dropdown(description='Preview as:', index=6, options=('Ratliff Macdonald <ratliffmacdonald@zola…
# <style>
#     .page-preview {
#         margin: -8px;
#         padding: 16px;
#         min-height: 256px;
#         border-top: 1px solid #555;
#         background-color: #FFFFFF;
#         color: #000000;
#         font-size: 16px;
#     }
# </style>
# <div class="page-preview">
#
# <div style="max-width: 685px;margin: 0 auto;padding: 4px;font-size: 16px;font-family: ui-sans-serif, system-ui, -apple-system, BlinkMacSystemFont, Segoe UI, Roboto, Helvetica Neue, Arial, Noto Sans, sans-serif, Apple Color Emoji, Segoe UI Emoji, Segoe UI Symbol, Noto Color Emoji">
# <strong style="margin: 0;padding: 0">News 📰</strong>
# <h1 style="margin: 0;font-size: 32px;padding: 0 0 32px 0">
#         Lorem ipsum dolor sit amet
#     </h1>
# <h2 style="margin: 0;padding: 0;font-size: 24px">
#         In metus est, sodales sit amet tellus id, fringilla gravida lorem
#     </h2>
# <strong style="margin: 0;padding: 0 0 16px 0;display: block">💸 ECONOMICS</strong>
# <figure style="padding: 0 0 16px 0;margin: 0 auto;max-width: 100%">
# <img alt="example image" src="https://images.unsplash.com/photo-1495020689067-958852a7765e?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&amp;ixlib=rb-1.2.1&amp;auto=format&amp;fit=crop&amp;w=2069&amp;q=80" style="margin: 0;padding: 0;width: 100%;display: block;border-radius: 5px"/>
# <figcaption style="margin: 0;padding: 0;text-align: center">Image: <a href="https://unsplash.com/photos/_Zua2hyvTBk" style="margin: 0;padding: 0">Unsplash</a></figcaption>
# </figure>
# <p style="margin: 0;padding: 0 0 16px 0">
#         Mauris volutpat pulvinar nunc, a mattis ex vehicula ac. Pellentesque molestie erat quis lacus porttitor, quis malesuada elit commodo. Mauris vehicula aliquam ligula at consequat. Sed pharetra dolor urna, posuere congue lorem porta a. In hac habitasse platea dictumst.
#     </p>
# <p style="margin: 0;padding: 0 0 16px 0">
#         Source: <a href="https://example.com" style="margin: 0;padding: 0">News</a>.
#     </p>
# <h1 style="margin: 0;padding: 16px 0 8px 0;font-size: 32px">
#         To the next, Luna! 👋
#     </h1>
# <p style="margin: 0;padding: 0 0 16px 0">
#         We always arrive at your inbox around 06:09. <b style="margin: 0;padding: 0">Some email servers are stubborn and slow… Others are even worse and throw us into spam and/or promotions. Whenever you can't find us in your inbox, look in these two.</b>
# </p>
# <hr style="padding: 0;margin: 16px 5%;border: none;border-top: 2px solid #EEE"/>
# <p style="margin: 0;padding: 0 0 16px 0;text-align: right">
# <em style="margin: 0;padding: 0">Luciano Felix, July 13 of 2022.<em style="margin: 0;padding: 0">
# </em></em></p>
# <p style="margin: 0;padding: 0 0 16px 0;text-align: center">
#         News, A newsletter example.
#         <br style="margin: 0;padding: 0"/>
#         200 R. Quatá, São Paulo - SP, 04546-041
#     </p>
# <p style="margin: 0;padding: 0 0 16px 0;text-align: center">
# <a href="#" style="margin: 0;padding: 0">Unsubscribe</a>
#         |
#         <a href="#" style="margin: 0;padding: 0">Contact us</a>
# </p>
# </div>
# </div>

# %% [markdown]
# ## **📄 Template**

# %%
# %%script html
# <template>
#
# <div class="container">
#     <strong>News 📰</strong>
#     <h1 class="title">
#         {{ title }}
#     </h1>
#
#     <h2>
#         In metus est, sodales sit amet tellus id, fringilla gravida lorem
#     </h2>
#     <strong>💸 ECONOMICS</strong>
#
#     <figure>
#         <img src="https://images.unsplash.com/photo-1495020689067-958852a7765e?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2069&q=80" alt="example image">
#
#         <figcaption>Image: <a href="https://unsplash.com/photos/_Zua2hyvTBk">Unsplash</a></figcaption>
#     </figure>
#
#     <p>
#         Mauris volutpat pulvinar nunc, a mattis ex vehicula ac. Pellentesque molestie erat quis lacus porttitor, quis malesuada elit commodo. Mauris vehicula aliquam ligula at consequat. Sed pharetra dolor urna, posuere congue lorem porta a. In hac habitasse platea dictumst.
#     </p>
#
#     <p>
#         Source: <a href="https://example.com">News</a>.
#     </p>
#
#     <h1>
#         To the next, {{ first_name }}! 👋
#     </h1>
#
#     <p>
#         We always arrive at your inbox around 06:09. <b>Some email servers are stubborn and slow… Others are even worse and throw us into spam and/or promotions. Whenever you can't find us in your inbox, look in these two.</b>
#     </p>
#
#     <hr>
#
#     <p class="right">
#         <em>Luciano Felix, {{ date }}.<em>
#     </p>
#
#     <p class="center">
#         News, A newsletter example.
#         <br>
#         200 R. Quatá, São Paulo - SP, 04546-041
#     </p>
#
#     <p class="center">
#         <a href="#">Unsubscribe</a>
#         |
#         <a href="#">Contact us</a>
#     </p>
# </div>
#
# </template>
# Out:
# Couldn't find program: 'html'

# %% [markdown]
# ## **🖌️ Style**

# %%
# %%script html
# <style type="text/css">
#
# @import url(public/style/normalize.css);
#
# .container {
#   max-width: 685px;
#   margin: 0 auto;
#   padding: 4px;
#   font-size: 16px;
#   font-family: ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;
# }
#
# h1 {
#   padding: 16px 0 8px 0;
#   font-size: 32px;
# }
#
# h1.title {
#   padding: 0 0 32px 0;
# }
#
# h2 {
#   font-size: 24px;
# }
#
# h2 + strong {
#   padding: 0 0 16px 0;
#   display: block;
# }
#
# p, figure {
#   padding: 0 0 16px 0;
# }
#
# figure {
#   margin: 0 auto;
#   max-width: 100%;
# }
#
# img {
#   width: 100%;
#   display: block;
#   border-radius: 5px;
# }
#
# figcaption {
#   text-align: center;
# }
#
# hr {
#   margin: 16px 5%;
#   border: none;
#   border-top: 2px solid #EEEEEE;
# }
#
# .center {
#   text-align: center;
# }
#
# .right {
#   text-align: right;
# }
#
# </style>
# Out:
# Couldn't find program: 'html'

# %% [markdown]
# ## 📧 Inbox

# %%
users
# Out:
#                  name                          email              phone
# 0   Ratliff Macdonald  ratliffmacdonald@zolarity.com  +1 (912) 445-2235
# 1    Arnold Castaneda   arnoldcastaneda@zolarity.com  +1 (835) 462-3358
# 2        Pope Clayton       popeclayton@zolarity.com  +1 (996) 512-2355
# 3      Patrice Curtis     patricecurtis@zolarity.com  +1 (989) 495-2477
# 4      Cora Blackburn     corablackburn@zolarity.com  +1 (937) 531-3046
# 5     Louella Russell    louellarussell@zolarity.com  +1 (997) 410-3892
# 6         Luna Decker        lunadecker@zolarity.com  +1 (982) 569-3624
# 7          Cole Hicks         colehicks@zolarity.com  +1 (945) 403-3546
# 8     Guthrie Baldwin    guthriebaldwin@zolarity.com  +1 (985) 501-2452
# 9       Holder Walter      holderwalter@zolarity.com  +1 (866) 482-2978
# 10     Ashley Trevino     ashleytrevino@zolarity.com  +1 (936) 468-3157
# 11       Sharp Norris       sharpnorris@zolarity.com  +1 (839) 578-2865
# 12    Frazier Miranda    fraziermiranda@zolarity.com  +1 (961) 573-3613
# 13     Bradford Hines     bradfordhines@zolarity.com  +1 (840) 566-3936
# 14  Gillespie Collins  gillespiecollins@zolarity.com  +1 (973) 502-2820
# 15         Allie Bell         alliebell@zolarity.com  +1 (827) 523-3773
